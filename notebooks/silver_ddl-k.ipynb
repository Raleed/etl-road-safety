# %%
# %run ./database_functions.ipynb
# %run ./dataframe_cleaning_functions.ipynb

# %%
from pathlib import Path
from typing import List, Optional
from sqlalchemy import create_engine
from psycopg2.extras import execute_values
from sqlalchemy_utils import database_exists, create_database
import logging
import pandas as pd
from sqlalchemy import text, Engine

CLEAN_DIR = Path("../data/cleaned")
RAW_DIR = Path("../data/raw")
CLEAN_DIR.mkdir(parents=True, exist_ok=True)
RAW_DIR.mkdir(parents=True, exist_ok=True)


logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

ADMIN_DB_URL = "postgresql+psycopg2://postgres:postgres2025%40@localhost:54785/postgres"
DB_NAME = "db_accident"
DB_URL = ADMIN_DB_URL.rsplit("/", 1)[0] + f"/{DB_NAME}"

# %%
script_silver_ddl = """
CREATE SCHEMA IF NOT EXISTS silver;

CREATE TABLE IF NOT EXISTS silver.caracteristiques (
  identifiant_de_l_accident VARCHAR(64),
  date_et_heure TIMESTAMP,
  jour SMALLINT,
  mois SMALLINT,
  annee SMALLINT,
  heure_minute TIME,
  date DATE,
  year_georef SMALLINT,
  lumiere VARCHAR(10),
  code_postal VARCHAR(10),
  code_insee VARCHAR(20),
  departement VARCHAR(6),
  commune VARCHAR(10),
  code_commune VARCHAR(10),
  code_officiel_commune VARCHAR(20),
  nom_officiel_commune VARCHAR(255),
  nom_officiel_commune_arrondissement_municipal VARCHAR(255),
  code_officiel_departement VARCHAR(10),
  nom_officiel_departement VARCHAR(255),
  code_officiel_region VARCHAR(10),
  nom_officiel_region VARCHAR(255),
  code_officiel_epci VARCHAR(20),
  nom_officiel_epci VARCHAR(255),
  localisation SMALLINT,
  intersection SMALLINT,
  conditions_atmospheriques SMALLINT,
  collision SMALLINT,
  adresse VARCHAR(512),
  gps CHAR(1),
  latitude DOUBLE PRECISION,
  longitude DOUBLE PRECISION,
  coordonnees VARCHAR(255),
  numero VARCHAR(64)
);

CREATE TABLE IF NOT EXISTS silver.lieux(
  identifiant_de_l_accident VARCHAR(64),
  categorie_route SMALLINT,
  voie VARCHAR(128),
  v1 VARCHAR(32),
  v2 VARCHAR(32),
  circulation SMALLINT,
  nombre_de_voies SMALLINT,
  voie_reservee SMALLINT,
  profil SMALLINT,
  pr VARCHAR(64),
  pr1 INT,
  plan SMALLINT,
  largeur_terre_plein_central DOUBLE PRECISION,
  largeur_de_la_chaussee DOUBLE PRECISION,
  surface SMALLINT,
  infrastructure SMALLINT,
  situation SMALLINT,
  env1 SMALLINT
);

CREATE TABLE IF NOT EXISTS silver.vehicules (
  identifiant_de_l_accident VARCHAR(64),
  identifiant_vehicule VARCHAR(64),
  sens SMALLINT,
  categorie_vehicule SMALLINT,
  obstacle_fixe_heurte SMALLINT,
  obstacle_mobile_heurte SMALLINT,
  point_de_choc SMALLINT,
  manoeuvre SMALLINT,
  nombre_d_occupants SMALLINT
);

CREATE TABLE IF NOT EXISTS silver.usagers (
  identifiant_de_l_accident VARCHAR(64),
  identifiant_vehicule VARCHAR(64),
  place VARCHAR(128),
  categorie_d_usager SMALLINT,
  gravite SMALLINT,
  sexe SMALLINT,
  annee_de_naissance SMALLINT,
  motif_trajet SMALLINT,
  existence_equipement_de_securite VARCHAR(8),
  utilisation_equipement_de_securite SMALLINT,
  localisation_du_pieton SMALLINT,
  action_pieton SMALLINT,
  pieton_seul_ou_non SMALLINT
);
"""
engine = get_engine(DB_URL) 
execute_script(engine, script_silver_ddl)
# Out:
# INFO:__main__:Exécution du script SQL...
# INFO:__main__:Script SQL exécuté avec succès
# INFO:__main__:Connexion fermée et engine libéré.

# %% [markdown]
# # 🧹 Nettoyage de la table `caracteristiques`

# %%
query = "SELECT COUNT(*) FROM bronze.caracteristiques_raw"
count= get_single_value(engine, query)
print(f"Nombre de lignes dans bronze.caracteristiques_raw : {count}")
# Out:
# Nombre de lignes dans bronze.caracteristiques_raw : 475911

# %%
#afficher un echantillon de 20 lignes
df_caracteristiques = get_df_from_table(engine, "bronze", "caracteristiques_raw")
# df_caracteristiques_sample = df_caracteristiques.sample(100, random_state=42)
# df_caracteristiques_sample.head()
df_caracteristiques.head()
# Out:
#   identifiant_de_l_accident              date_et_heure jour mois annee  \
# 0              201700033619  2017-05-19T17:40:00+02:00   19   05  2017
# 1              201700048262  2017-12-25T17:55:00+01:00   25   12  2017
# 2              201700048288  2017-01-01T17:25:00+01:00   01   01  2017
# 3              201700048486  2017-05-04T00:04:00+02:00   04   05  2017
# 4              201700048639  2017-07-11T08:10:00+02:00   11   07  2017
#
#   heure_minute  date year_georef                                lumiere  \
# 0        17:40  None        2017                             Plein jour
# 1        17:55  None        2017                     Crépuscule ou aube
# 2        17:25  None        2017             Nuit sans éclairage public
# 3        00:04  None        2017  Nuit avec éclairage public non allumé
# 4        08:10  None        2017                             Plein jour
#
#   code_postal  ...        localisation intersection conditions_atmospheriques  \
# 0       66100  ...  Hors agglomération            6                   Normale
# 1       93200  ...  Hors agglomération            1                   Normale
# 2       92230  ...  Hors agglomération            1             Temps couvert
# 3       78330  ...  Hors agglomération            1                     Autre
# 4       78140  ...  Hors agglomération            1                   Normale
#
#                              collision                   adresse        gps  \
# 0       Deux véhicules – par l’arrière  COPENHAGUE (ROND POINT D  Métropole
# 1  Trois véhicules et plus – en chaîne              AUTOROUTE A1  Métropole
# 2  Trois véhicules et plus – en chaîne                       A86       None
# 3                      Autre collision                     A12 Y  Métropole
# 4         Deux véhicules – par le coté                      N118  Métropole
#
#   latitude longitude          coordonnees numero
# 0  4269110   0285200  42.668322, 2.897617   None
# 1     None      None                 None      1
# 2     None      None  48.925197, 2.293085     86
# 3  4880700   0205200  48.812878, 2.048119     12
# 4  4878430   0222310  48.783326, 2.187486    118
#
# [5 rows x 33 columns]

# %%
# Supprimer les doublons
print(f"Nombre de lignes avant suppression des doublons : {df_caracteristiques.shape[0]}")
df_caracteristiques = df_caracteristiques.drop_duplicates()
print(f"Nombre de lignes après suppression des doublons : {df_caracteristiques.shape[0]}")

#remplacer les valeurs nulles
remplacer_valeurs_null(df_caracteristiques)
# Out:
# Nombre de lignes avant suppression des doublons : 475911
# Nombre de lignes après suppression des doublons : 475911
#        identifiant_de_l_accident              date_et_heure jour mois annee  \
# 0                   201700033619  2017-05-19T17:40:00+02:00   19   05  2017
# 1                   201700048262  2017-12-25T17:55:00+01:00   25   12  2017
# 2                   201700048288  2017-01-01T17:25:00+01:00   01   01  2017
# 3                   201700048486  2017-05-04T00:04:00+02:00   04   05  2017
# 4                   201700048639  2017-07-11T08:10:00+02:00   11   07  2017
# ...                          ...                        ...  ...  ...   ...
# 475906              201600004642  2016-01-01T05:00:00+01:00   01   01  2016
# 475907              201600004875  2016-07-27T16:15:00+02:00   27   07  2016
# 475908              201600000781  2016-01-14T08:00:00+01:00   14   01  2016
# 475909              201400047990  2014-03-08T17:15:00+01:00   08   03  2014
# 475910              201300057095  2013-04-16T22:45:00+02:00   16   04  2013
#
#        heure_minute     date year_georef  \
# 0             17:40  Inconnu        2017
# 1             17:55  Inconnu        2017
# 2             17:25  Inconnu        2017
# 3             00:04  Inconnu        2017
# 4             08:10  Inconnu        2017
# ...             ...      ...         ...
# 475906        05:00  Inconnu        2016
# 475907        16:15  Inconnu        2016
# 475908        08:00  Inconnu        2016
# 475909        17:15  Inconnu        2015
# 475910        22:45  Inconnu        2015
#
#                                       lumiere code_postal  ...  \
# 0                                  Plein jour       66100  ...
# 1                          Crépuscule ou aube       93200  ...
# 2                  Nuit sans éclairage public       92230  ...
# 3       Nuit avec éclairage public non allumé       78330  ...
# 4                                  Plein jour       78140  ...
# ...                                       ...         ...  ...
# 475906             Nuit sans éclairage public       01290  ...
# 475907                             Plein jour       38530  ...
# 475908      Nuit avec éclairage public allumé       27400  ...
# 475909                             Plein jour       92210  ...
# 475910             Nuit sans éclairage public     Inconnu  ...
#
#               localisation intersection conditions_atmospheriques  \
# 0       Hors agglomération            6                   Normale
# 1       Hors agglomération            1                   Normale
# 2       Hors agglomération            1             Temps couvert
# 3       Hors agglomération            1                     Autre
# 4       Hors agglomération            1                   Normale
# ...                    ...          ...                       ...
# 475906    En agglomération            1        Brouillard - fumée
# 475907    En agglomération            9                   Normale
# 475908    En agglomération            2               Pluie forte
# 475909  Hors agglomération            1                   Normale
# 475910  Hors agglomération            1                   Normale
#
#                                              collision  \
# 0                       Deux véhicules – par l’arrière
# 1                  Trois véhicules et plus – en chaîne
# 2                  Trois véhicules et plus – en chaîne
# 3                                      Autre collision
# 4                         Deux véhicules – par le coté
# ...                                                ...
# 475906                       Deux véhicules - frontale
# 475907                                 Autre collision
# 475908                       Deux véhicules - frontale
# 475909  Trois véhicules et plus - collisions multiples
# 475910                                 Autre collision
#
#                          adresse        gps latitude longitude  \
# 0       COPENHAGUE (ROND POINT D  Métropole  4269110   0285200
# 1                   AUTOROUTE A1  Métropole  Inconnu   Inconnu
# 2                            A86    Inconnu  Inconnu   Inconnu
# 3                          A12 Y  Métropole  4880700   0205200
# 4                           N118  Métropole  4878430   0222310
# ...                          ...        ...      ...       ...
# 475906              Les Allouets  Métropole  Inconnu   Inconnu
# 475907     parking av de la gare  Métropole  Inconnu   Inconnu
# 475908                    RD 164  Métropole  Inconnu   Inconnu
# 475909                       A13    Inconnu  Inconnu   Inconnu
# 475910                   Inconnu    Réunion  Inconnu   Inconnu
#
#                 coordonnees   numero
# 0       42.668322, 2.897617  Inconnu
# 1                   Inconnu        1
# 2       48.925197, 2.293085       86
# 3       48.812878, 2.048119       12
# 4       48.783326, 2.187486      118
# ...                     ...      ...
# 475906   46.21663, 4.951376  Inconnu
# 475907  45.433123, 6.015207  Inconnu
# 475908              Inconnu      164
# 475909  48.845569, 2.215131       13
# 475910              Inconnu  Inconnu
#
# [475911 rows x 33 columns]

# %%
#changer type de colonne date_et_heure

df_caracteristiques['date_et_heure'] =pd.to_datetime(

    df_caracteristiques['date_et_heure'],
    errors='raise',
    utc=True
    ).to_frame()
# df_caracteristiques_sample.drop(['annee', 'mois', 'jour', 'heure_minute'], axis=1, inplace=True) 
df_caracteristiques
# Out:
#        identifiant_de_l_accident             date_et_heure jour mois annee  \
# 0                   201700033619 2017-05-19 15:40:00+00:00   19   05  2017
# 1                   201700048262 2017-12-25 16:55:00+00:00   25   12  2017
# 2                   201700048288 2017-01-01 16:25:00+00:00   01   01  2017
# 3                   201700048486 2017-05-03 22:04:00+00:00   04   05  2017
# 4                   201700048639 2017-07-11 06:10:00+00:00   11   07  2017
# ...                          ...                       ...  ...  ...   ...
# 475906              201600004642 2016-01-01 04:00:00+00:00   01   01  2016
# 475907              201600004875 2016-07-27 14:15:00+00:00   27   07  2016
# 475908              201600000781 2016-01-14 07:00:00+00:00   14   01  2016
# 475909              201400047990 2014-03-08 16:15:00+00:00   08   03  2014
# 475910              201300057095 2013-04-16 20:45:00+00:00   16   04  2013
#
#        heure_minute  date year_georef                                lumiere  \
# 0             17:40  None        2017                             Plein jour
# 1             17:55  None        2017                     Crépuscule ou aube
# 2             17:25  None        2017             Nuit sans éclairage public
# 3             00:04  None        2017  Nuit avec éclairage public non allumé
# 4             08:10  None        2017                             Plein jour
# ...             ...   ...         ...                                    ...
# 475906        05:00  None        2016             Nuit sans éclairage public
# 475907        16:15  None        2016                             Plein jour
# 475908        08:00  None        2016      Nuit avec éclairage public allumé
# 475909        17:15  None        2015                             Plein jour
# 475910        22:45  None        2015             Nuit sans éclairage public
#
#        code_postal  ...        localisation intersection  \
# 0            66100  ...  Hors agglomération            6
# 1            93200  ...  Hors agglomération            1
# 2            92230  ...  Hors agglomération            1
# 3            78330  ...  Hors agglomération            1
# 4            78140  ...  Hors agglomération            1
# ...            ...  ...                 ...          ...
# 475906       01290  ...    En agglomération            1
# 475907       38530  ...    En agglomération            9
# 475908       27400  ...    En agglomération            2
# 475909       92210  ...  Hors agglomération            1
# 475910        None  ...  Hors agglomération            1
#
#        conditions_atmospheriques  \
# 0                        Normale
# 1                        Normale
# 2                  Temps couvert
# 3                          Autre
# 4                        Normale
# ...                          ...
# 475906        Brouillard - fumée
# 475907                   Normale
# 475908               Pluie forte
# 475909                   Normale
# 475910                   Normale
#
#                                              collision  \
# 0                       Deux véhicules – par l’arrière
# 1                  Trois véhicules et plus – en chaîne
# 2                  Trois véhicules et plus – en chaîne
# 3                                      Autre collision
# 4                         Deux véhicules – par le coté
# ...                                                ...
# 475906                       Deux véhicules - frontale
# 475907                                 Autre collision
# 475908                       Deux véhicules - frontale
# 475909  Trois véhicules et plus - collisions multiples
# 475910                                 Autre collision
#
#                          adresse        gps latitude longitude  \
# 0       COPENHAGUE (ROND POINT D  Métropole  4269110   0285200
# 1                   AUTOROUTE A1  Métropole     None      None
# 2                            A86       None     None      None
# 3                          A12 Y  Métropole  4880700   0205200
# 4                           N118  Métropole  4878430   0222310
# ...                          ...        ...      ...       ...
# 475906              Les Allouets  Métropole     None      None
# 475907     parking av de la gare  Métropole     None      None
# 475908                    RD 164  Métropole     None      None
# 475909                       A13       None     None      None
# 475910                      None    Réunion     None      None
#
#                 coordonnees numero
# 0       42.668322, 2.897617   None
# 1                      None      1
# 2       48.925197, 2.293085     86
# 3       48.812878, 2.048119     12
# 4       48.783326, 2.187486    118
# ...                     ...    ...
# 475906   46.21663, 4.951376   None
# 475907  45.433123, 6.015207   None
# 475908                 None    164
# 475909  48.845569, 2.215131     13
# 475910                 None   None
#
# [475911 rows x 33 columns]

# %%
#Harmonisation de la colonne 'intersection'
print(df_caracteristiques.groupby('intersection').size().reset_index(name='counts').sort_values(by='counts', ascending=False))
mapping_intersection = {
    '0': 'non renseigné',
    '1': 'hors intersection',
    '2': 'intersection en x',
    '3': 'intersection en t',
    '4': 'intersection en y',
    '5': 'intersection à plus de 4 branches',
    '6': 'giratoire',
    '7': 'place',
    '8': 'passage à niveau',
    '9': 'autre intersection'
}
harmonise_colonne_df(df_caracteristiques,'intersection',mapping_intersection)
print('\napres harmonisation:')
print(df_caracteristiques.groupby('intersection').size().reset_index(name='counts').sort_values(by='counts', ascending=False))
# Out:
#   intersection  counts
# 1            1  328937
# 2            2   56882
# 3            3   44672
# 6            6   15386
# 9            9   10060
# 4            4    8361
# 7            7    6100
# 5            5    4833
# 8            8     590
# 0            0      90
#
# apres harmonisation:
#                         intersection  counts
# 2                  hors intersection  328937
# 4                  intersection en x   56882
# 3                  intersection en t   44672
# 1                          giratoire   15386
# 0                 autre intersection   10060
# 5                  intersection en y    8361
# 9                              place    6100
# 6  intersection à plus de 4 branches    4833
# 8                   passage à niveau     590
# 7                      non renseigné      90

# %%
# -1 
print(df_caracteristiques.groupby('collision').size().reset_index(name='counts').sort_values(by='counts', ascending=False))

df_caracteristiques = remplacer_valeur(
    df_caracteristiques,
    'collision',
    '-1',
    'Inconnu'
)
print(df_caracteristiques.groupby('collision').size().reset_index(name='counts').sort_values(by='counts', ascending=False))
# Out:
#                                         collision  counts
# 1                                 Autre collision  161298
# 3                    Deux véhicules – par le coté  132605
# 4                  Deux véhicules – par l’arrière   58352
# 5                                  Sans collision   46028
# 2                       Deux véhicules - frontale   45192
# 7             Trois véhicules et plus – en chaîne   16916
# 6  Trois véhicules et plus - collisions multiples   15508
# 0                                              -1       2
#                                         collision  counts
# 0                                 Autre collision  161298
# 2                    Deux véhicules – par le coté  132605
# 3                  Deux véhicules – par l’arrière   58352
# 5                                  Sans collision   46028
# 1                       Deux véhicules - frontale   45192
# 7             Trois véhicules et plus – en chaîne   16916
# 6  Trois véhicules et plus - collisions multiples   15508
# 4                                         Inconnu       2

# %%
#supprimer les colonnes avec missing values supérieures à 50%
# col_a_supprimer = ['infrastructure']

# df_caracteristiques = supprimer_colonnes(df_caracteristiques, col_a_supprimer)

df_caracteristiques
# Out:
#        identifiant_de_l_accident             date_et_heure jour mois annee  \
# 0                   201700033619 2017-05-19 15:40:00+00:00   19   05  2017
# 1                   201700048262 2017-12-25 16:55:00+00:00   25   12  2017
# 2                   201700048288 2017-01-01 16:25:00+00:00   01   01  2017
# 3                   201700048486 2017-05-03 22:04:00+00:00   04   05  2017
# 4                   201700048639 2017-07-11 06:10:00+00:00   11   07  2017
# ...                          ...                       ...  ...  ...   ...
# 475906              201600004642 2016-01-01 04:00:00+00:00   01   01  2016
# 475907              201600004875 2016-07-27 14:15:00+00:00   27   07  2016
# 475908              201600000781 2016-01-14 07:00:00+00:00   14   01  2016
# 475909              201400047990 2014-03-08 16:15:00+00:00   08   03  2014
# 475910              201300057095 2013-04-16 20:45:00+00:00   16   04  2013
#
#        heure_minute  date year_georef                                lumiere  \
# 0             17:40  None        2017                             Plein jour
# 1             17:55  None        2017                     Crépuscule ou aube
# 2             17:25  None        2017             Nuit sans éclairage public
# 3             00:04  None        2017  Nuit avec éclairage public non allumé
# 4             08:10  None        2017                             Plein jour
# ...             ...   ...         ...                                    ...
# 475906        05:00  None        2016             Nuit sans éclairage public
# 475907        16:15  None        2016                             Plein jour
# 475908        08:00  None        2016      Nuit avec éclairage public allumé
# 475909        17:15  None        2015                             Plein jour
# 475910        22:45  None        2015             Nuit sans éclairage public
#
#        code_postal  ...        localisation        intersection  \
# 0            66100  ...  Hors agglomération           giratoire
# 1            93200  ...  Hors agglomération   hors intersection
# 2            92230  ...  Hors agglomération   hors intersection
# 3            78330  ...  Hors agglomération   hors intersection
# 4            78140  ...  Hors agglomération   hors intersection
# ...            ...  ...                 ...                 ...
# 475906       01290  ...    En agglomération   hors intersection
# 475907       38530  ...    En agglomération  autre intersection
# 475908       27400  ...    En agglomération   intersection en x
# 475909       92210  ...  Hors agglomération   hors intersection
# 475910        None  ...  Hors agglomération   hors intersection
#
#        conditions_atmospheriques  \
# 0                        Normale
# 1                        Normale
# 2                  Temps couvert
# 3                          Autre
# 4                        Normale
# ...                          ...
# 475906        Brouillard - fumée
# 475907                   Normale
# 475908               Pluie forte
# 475909                   Normale
# 475910                   Normale
#
#                                              collision  \
# 0                       Deux véhicules – par l’arrière
# 1                  Trois véhicules et plus – en chaîne
# 2                  Trois véhicules et plus – en chaîne
# 3                                      Autre collision
# 4                         Deux véhicules – par le coté
# ...                                                ...
# 475906                       Deux véhicules - frontale
# 475907                                 Autre collision
# 475908                       Deux véhicules - frontale
# 475909  Trois véhicules et plus - collisions multiples
# 475910                                 Autre collision
#
#                          adresse        gps latitude longitude  \
# 0       COPENHAGUE (ROND POINT D  Métropole  4269110   0285200
# 1                   AUTOROUTE A1  Métropole     None      None
# 2                            A86       None     None      None
# 3                          A12 Y  Métropole  4880700   0205200
# 4                           N118  Métropole  4878430   0222310
# ...                          ...        ...      ...       ...
# 475906              Les Allouets  Métropole     None      None
# 475907     parking av de la gare  Métropole     None      None
# 475908                    RD 164  Métropole     None      None
# 475909                       A13       None     None      None
# 475910                      None    Réunion     None      None
#
#                 coordonnees numero
# 0       42.668322, 2.897617   None
# 1                      None      1
# 2       48.925197, 2.293085     86
# 3       48.812878, 2.048119     12
# 4       48.783326, 2.187486    118
# ...                     ...    ...
# 475906   46.21663, 4.951376   None
# 475907  45.433123, 6.015207   None
# 475908                 None    164
# 475909  48.845569, 2.215131     13
# 475910                 None   None
#
# [475911 rows x 33 columns]

# %% [markdown]
# # 🧹 Nettoyage de la table Véhicule

# %%
df_vehicles = get_df_from_table(engine, "bronze", "vehicules_raw")
df_vehicles.head()
# Out:
#   identifiant_de_l_accident identifiant_vehicule  \
# 0              201700033619              B01,A01
# 1              201700048262  A01,E01,C01,B01,D01
# 2              201700048288      D01,B01,A01,C01
# 3              201700048486              A01,B01
# 4              201700048639              Z01,A01
#
#                                                 sens  \
# 0                                               None
# 1  PK ou PR ou numéro d’adresse postale croissant...
# 2  PK ou PR ou numéro d’adresse postale décroissa...
# 3  PK ou PR ou numéro d’adresse postale croissant...
# 4  PK ou PR ou numéro d’adresse postale décroissa...
#
#                         categorie_vehicule obstacle_fixe_heurte  \
# 0                          VL seul,VL seul                 None
# 1  VL seul,VL seul,VL seul,VL seul,VL seul                 None
# 2          VL seul,VL seul,VL seul,VL seul                 None
# 3                          VL seul,VL seul                 None
# 4           VL seul,Motocyclette > 125 cm3                 None
#
#                          obstacle_mobile_heurte  \
# 0                             Véhicule,Véhicule
# 1  Véhicule,Véhicule,Véhicule,Véhicule,Véhicule
# 2           Véhicule,Véhicule,Véhicule,Véhicule
# 3                             Véhicule,Véhicule
# 4                             Véhicule,Véhicule
#
#                                        point_de_choc  \
# 0                                      Arrière,Avant
# 1  Avant droit,Arrière,Côté gauche,Arrière droit,...
# 2                        Arrière,Avant,Avant,Arrière
# 3                           Avant gauche,Côté gauche
# 4                                        Avant droit
#
#                                            manoeuvre nombre_d_occupants
# 0                       Sans changement de direction               None
# 1  Manœuvre d’évitement,Arrêté (hors stationnemen...               None
# 2            Même sens,Même sens,Même sens,Même sens               None
# 3        Changeant de file A gauche,Déporté A gauche               None
# 4                       Sans changement de direction               None

# %%
#supprimer les colonnes avec missing values supérieures à 50%
col_a_supprimer = ['sens', 'obstacle_fixe_heurte', 'obstacle_mobile_heurte', 'nombre_d_occupants']
df_vehicles = supprimer_colonnes(df_vehicles, col_a_supprimer)

# %% [markdown]
# # 🧹 Nettoyage de la table usagers

# %%
df_usagers = get_df_from_table(engine, "bronze", "usagers_raw")
df_usagers.head()
# Out:
#   identifiant_de_l_accident identifiant_vehicule      place  \
# 0              201700033619              B01,A01    1,1,2,2
# 1              201700048262  A01,E01,C01,B01,D01  1,1,1,1,1
# 2              201700048288      D01,B01,A01,C01  1,1,1,2,1
# 3              201700048486              A01,B01      1,1,2
# 4              201700048639              Z01,A01        1,1
#
#                                   categorie_d_usager  \
# 0            Conducteur,Conducteur,Passager,Passager
# 1  Conducteur,Conducteur,Conducteur,Conducteur,Co...
# 2  Conducteur,Conducteur,Conducteur,Passager,Cond...
# 3                     Conducteur,Conducteur,Passager
# 4                              Conducteur,Conducteur
#
#                                   gravite  \
# 0             Blessé,Blessé,Blessé,Blessé
# 1  Indemne,Indemne,Blessé,Indemne,Indemne
# 2  Indemne,Indemne,Indemne,Blessé,Indemne
# 3                   Blessé,Indemne,Blessé
# 4                          Indemne,Blessé
#
#                                            sexe        annee_de_naissance  \
# 0           Masculin,Masculin,Masculin,Masculin       1996,1939,1996,1931
# 1    Masculin,Masculin,Féminin,Féminin,Masculin  1952,1934,1979,1986,1978
# 2  Masculin,Masculin,Masculin,Masculin,Masculin  1982,1978,1990,2004,1978
# 3                    Masculin,Masculin,Masculin            1992,1990,1992
# 4                             Masculin,Masculin                 1992,1960
#
#                                         motif_trajet  \
# 0  Promenade – loisirs,Promenade – loisirs,Promen...
# 1                                               None
# 2                                               None
# 3                                              Autre
# 4              Domicile – travail,Domicile – travail
#
#                existence_equipement_de_securite  \
# 0           Ceinture,Ceinture,Ceinture,Ceinture
# 1  Ceinture,Ceinture,Ceinture,Ceinture,Ceinture
# 2  Ceinture,Ceinture,Ceinture,Ceinture,Ceinture
# 3                    Ceinture,Ceinture,Ceinture
# 4                               Ceinture,Casque
#
#   utilisation_equipement_de_securite localisation_du_pieton  \
# 0                    Oui,Oui,Oui,Oui                   None
# 1                Oui,Oui,Oui,Oui,Oui                   None
# 2                Oui,Oui,Oui,Oui,Oui                   None
# 3                        Oui,Oui,Oui                   None
# 4                            Oui,Oui                   None
#
#                                        action_pieton pieton_seul_ou_non
# 0  Se déplaçant,Se déplaçant,Se déplaçant,Se dépl...               None
# 1  Se déplaçant,Se déplaçant,Se déplaçant,Se dépl...               None
# 2  Se déplaçant,Se déplaçant,Se déplaçant,Se dépl...               None
# 3             Se déplaçant,Se déplaçant,Se déplaçant               None
# 4                          Se déplaçant,Se déplaçant               None

# %%
#supprimer les colonnes avec missing values supérieures à 50%
col_a_supprimer = ['localisation_du_pieton', 'pieton_seul_ou_non']
df_usagers = supprimer_colonnes(df_usagers, col_a_supprimer)

# %%
#Harmonisation de la colonne 'sexe'
# prend les 2 premiers caractères
df_usagers['sexe'] = df_usagers['sexe'].astype(str).str[:2].str.lower().str.replace(' ', '')  
df_usagers.groupby('sexe').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
mapping_sexe = {
    'ma': 'homme',
    'fé': 'femme'
}
harmonise_colonne_df(df_usagers,'sexe',mapping_sexe)
print('\napres harmonisation:')
print(df_usagers.groupby('sexe').size().reset_index(name='counts').sort_values(by='counts', ascending=False))
# Out:
# apres harmonisation:
#     sexe  counts
# 1  homme  332112
# 0  femme  143799

# %%
df_usagers.head(1)
# Out:
#   identifiant_de_l_accident identifiant_vehicule    place  \
# 0              201700033619              B01,A01  1,1,2,2
#
#                         categorie_d_usager                      gravite  \
# 0  Conducteur,Conducteur,Passager,Passager  Blessé,Blessé,Blessé,Blessé
#
#     sexe   annee_de_naissance  \
# 0  homme  1996,1939,1996,1931
#
#                                         motif_trajet  \
# 0  Promenade – loisirs,Promenade – loisirs,Promen...
#
#       existence_equipement_de_securite utilisation_equipement_de_securite  \
# 0  Ceinture,Ceinture,Ceinture,Ceinture                    Oui,Oui,Oui,Oui
#
#                                        action_pieton
# 0  Se déplaçant,Se déplaçant,Se déplaçant,Se dépl...

# %%
# df_usagers.groupby('categorie_d_usager').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# df_usagers.groupby('gravite').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# df_usagers.groupby('gravite').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# df_usagers.groupby('motif_trajet').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# df_usagers.groupby('motif_trajet').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# df_usagers.groupby('existence_equipement_de_securite').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# df_usagers.groupby('utilisation_equipement_de_securite').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
df_usagers.groupby('action_pieton').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# Out:
#                                          action_pieton  counts
# 520                          Se déplaçant,Se déplaçant  182556
# 312                                       Se déplaçant   78113
# 617             Se déplaçant,Se déplaçant,Se déplaçant   58645
# 792                            Se déplaçant,Traversant   25868
# 847                            Traversant,Se déplaçant   23818
# ..                                                 ...     ...
# 889              Traversant,Traversant,Se déplaçant,-1       1
# 890           Traversant,Traversant,Se déplaçant,Autre       1
# 891  Traversant,Traversant,Se déplaçant,Autre,Trave...       1
# 38               -1,-1,-1,Se déplaçant,Se déplaçant,-1       1
# 892               Traversant,Traversant,Se déplaçant,B       1
#
# [910 rows x 2 columns]

# %%
# Out:
# INFO:__main__:Exécution du script SQL...
# INFO:__main__:Script SQL exécuté avec succès
# INFO:__main__:Connexion fermée et engine libéré.
